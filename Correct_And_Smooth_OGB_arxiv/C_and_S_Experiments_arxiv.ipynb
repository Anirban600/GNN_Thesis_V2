# %%
# !python3 main.py \
    --dataset ogbn-arxiv \
    --model linear \
    --dropout 0.5 \
    --epochs 1000 \
    --lr 0.1
# Out:
# WARNING:root:The OGB package is out of date. Your version is 1.3.5, while the latest version is 1.3.6.
# ...
# Downloaded 0.08 GB: 100%|███████████████████████| 81/81 [01:10<00:00,  1.15it/s]
# Extracting dataset/arxiv.zip
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████████████████████████████████████| 1/1 [00:00<00:00, 29127.11it/s]
# Converting graphs into DGL objects...
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 33.84it/s]
# Saving...
# Model parameters: 5160
# ---------- Training ----------
# Epoch 0 | Train loss: 3.8634 | Train acc: 0.3402 | Valid acc 0.3121
# Epoch 1 | Train loss: 2.6007 | Train acc: 0.4506 | Valid acc 0.4511
# Epoch 2 | Train loss: 2.3508 | Train acc: 0.4820 | Valid acc 0.4827
# Epoch 3 | Train loss: 2.3210 | Train acc: 0.4920 | Valid acc 0.4957
# Epoch 4 | Train loss: 2.3547 | Train acc: 0.5015 | Valid acc 0.5030
# Epoch 5 | Train loss: 2.3478 | Train acc: 0.5081 | Valid acc 0.5095
# ...

# %%
# !python3 main.py \
    --dataset ogbn-arxiv \
    --model linear \
    --pretrain \
    --correction-alpha 1. \
    --smoothing-alpha 0.9
# Out:
# WARNING:root:The OGB package is out of date. Your version is 1.3.5, while the latest version is 1.3.6.
# Model parameters: 5160
# ---------- Before ----------
# Valid acc: 0.5512 | Test acc: 0.5276
# ---------- Correct & Smoothing ----------
# Valid acc: 0.6952 | Test acc: 0.6819
# Predictions Saved...
