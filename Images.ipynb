# %% [markdown]
# ## Pre-Processing

# %%
# !pip install dgl-cu111 dglgo -f https://data.dgl.ai/wheels/repo.html
# !pip install ogb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.dgl.ai/wheels/repo.html
# ...
#      |████████████████████████████████| 252.8 MB 17 kB/s
# ...
#      |████████████████████████████████| 77 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 51 kB 504 kB/s
# ...
#      |████████████████████████████████| 45 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 103 kB 30.0 MB/s
# ...
#      |████████████████████████████████| 109 kB 69.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 77.8 MB/s
# ...
#      |████████████████████████████████| 11.1 MB 83.9 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.0 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 86.7 MB/s
# ...
#      |████████████████████████████████| 546 kB 84.7 MB/s
# ...
#      |████████████████████████████████| 90 kB 11.2 MB/s
# ...
#      |████████████████████████████████| 84 kB 3.9 MB/s
# ...
#      |████████████████████████████████| 121 kB 87.7 MB/s
# ...

# %% [markdown]
# # CIFAR-10 -> MobileNetV2

# %%
# !python3 /content/drive/MyDrive/GAT/dgl-master/examples/pytorch/gat/train.py \
                                                            --dataset "cifar10-mobnet" \
                                                            --gpu 0 \
                                                            --early-stop
# Out:
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)
# Namespace(agg_type='cat', attn_drop=0.6, aug_khop=False, dataset='cifar10-mobnet', early_stop=True, epochs=2000, fastmode=False, gpu=0, in_drop=0.6, lr=0.005, lsh_add=False, min_epochs=0, n_iter=5, negative_slope=0.2, num_heads=8, num_hidden=8, num_layers=2, num_out_heads=1, out_agg_type='cat', residual=False, weight_decay=0.0005)
# Loading cifar10-mobnet dataset.
# loading representations from  /content/drive/MyDrive/GNNOnImage/output_complete.pickle
# features copy shape  (60000, 1280)
# 100% 60000/60000 [49:13<00:00, 20.31it/s]
# khop = False add = False
# ----Data statistics------'
#       #Edges 636089
#       #Classes 10
#       #Train samples 45000
#       #Val samples 5000
#       #Test samples 10000
# GAT(
# ...

# %%
# !python3 /content/drive/MyDrive/GAT/dgl-master/examples/pytorch/ogb/ogbn-arxiv/gat.py \
                                                                 --dataset "cifar10-mobnet" \
                                                                 --n-runs 5 \
                                                                 --use-norm \
                                                                 --use-labels \
                                                                 --no-attn-dst \
                                                                 --edge-drop 0.1 \
                                                                 --input-drop 0.1 \
                                                                 --early_stopping
# Out:
# Loading cifar10-mobnet dataset.
# loading representations from  /content/drive/MyDrive/GNNOnImage/output_complete.pickle
# features copy shape  (60000, 1280)
# 100% 60000/60000 [47:08<00:00, 21.21it/s]
# torch.Size([60000, 1280])
# khop = False add = False
# ----Data statistics------'
#       #Edges 909008
#       #Classes 10
#       #Train samples 45000
#       #Val samples 5000
#       #Test samples 10000
# ----------------------------------------
# Run: 1/5, Epoch: 20/2000, Average epoch time: 0.18  Patience 0 / 100
# Loss: 0.2183, Acc: 0.9301   Train/Val/Test loss: 0.2057/0.1533/0.1710
# Train/Val/Test/Best val/Final test acc: 0.9322/0.9506/0.9434/0.9506/0.9434
# ----------------------------------------
# Run: 1/5, Epoch: 40/2000, Average epoch time: 0.17  Patience 14 / 100
# Loss: 0.2108, Acc: 0.9306   Train/Val/Test loss: 0.1986/0.1470/0.1654
# Train/Val/Test/Best val/Final test acc: 0.9347/0.9520/0.9441/0.9508/0.9444
# ----------------------------------------
# ...

# %% [markdown]
# # CIFAR-10 -> GoogleNet

# %%
# !python3 /content/drive/MyDrive/GAT/dgl-master/examples/pytorch/gat/train.py \
                                                            --dataset "cifar10-gnet" \
                                                            --gpu 0 \
                                                            --early-stop
# Out:
# Namespace(agg_type='cat', attn_drop=0.6, aug_khop=False, dataset='cifar10-gnet', early_stop=True, epochs=2000, fastmode=False, gpu=0, in_drop=0.6, lr=0.005, lsh_add=False, min_epochs=0, n_iter=5, negative_slope=0.2, num_heads=8, num_hidden=8, num_layers=2, num_out_heads=1, out_agg_type='cat', residual=False, weight_decay=0.0005)
# Loading cifar10-gnet dataset.
# loading representations from  /content/drive/MyDrive/GNNOnImage/gnet_cifar10_emb_complete.pickle
# features copy shape  (60000, 1024)
# 100% 60000/60000 [37:45<00:00, 26.48it/s]
# khop = False add = False
# ----Data statistics------'
#       #Edges 654856
#       #Classes 10
#       #Train samples 45000
#       #Val samples 5000
#       #Test samples 10000
# GAT(
#   (gat_layers): ModuleList(
#     (0): GATConv(
#       (fc): Linear(in_features=1024, out_features=64, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
# ...

# %%
# !python3 /content/drive/MyDrive/GAT/dgl-master/examples/pytorch/ogb/ogbn-arxiv/gat.py \
                                                                 --dataset "cifar10-gnet" \
                                                                 --n-runs 5 \
                                                                 --use-norm \
                                                                 --use-labels \
                                                                 --no-attn-dst \
                                                                 --edge-drop 0.1 \
                                                                 --input-drop 0.1 \
                                                                 --early_stopping
# Out:
# Loading cifar10-gnet dataset.
# loading representations from  /content/drive/MyDrive/GNNOnImage/gnet_cifar10_emb_complete.pickle
# features copy shape  (60000, 1024)
# 100% 60000/60000 [39:25<00:00, 25.37it/s]
# torch.Size([60000, 1024])
# khop = False add = False
# ----Data statistics------'
#       #Edges 932218
#       #Classes 10
#       #Train samples 45000
#       #Val samples 5000
#       #Test samples 10000
# ----------------------------------------
# Run: 1/5, Epoch: 20/2000, Average epoch time: 0.18  Patience 1 / 100
# Loss: 0.1115, Acc: 0.9679   Train/Val/Test loss: 0.1027/0.0618/0.0517
# Train/Val/Test/Best val/Final test acc: 0.9698/0.9834/0.9881/0.9850/0.9870
# ----------------------------------------
# Run: 1/5, Epoch: 40/2000, Average epoch time: 0.17  Patience 1 / 100
# Loss: 0.0986, Acc: 0.9688   Train/Val/Test loss: 0.0909/0.0429/0.0370
# Train/Val/Test/Best val/Final test acc: 0.9707/0.9856/0.9875/0.9864/0.9883
# ----------------------------------------
# ...

# %% [markdown]
# # F-MNIST

# %%
# !python3 /content/drive/MyDrive/GAT/dgl-master/examples/pytorch/gat/train.py \
                                                            --dataset "fmnist" \
                                                            --gpu 0 \
                                                            --early-stop
# Out:
# Namespace(agg_type='cat', attn_drop=0.6, aug_khop=False, dataset='fmnist', early_stop=True, epochs=2000, fastmode=False, gpu=0, in_drop=0.6, lr=0.005, lsh_add=False, min_epochs=0, n_iter=5, negative_slope=0.2, num_heads=8, num_hidden=8, num_layers=2, num_out_heads=1, out_agg_type='cat', residual=False, weight_decay=0.0005)
# Loading fmnist dataset.
# loading representations from  /content/drive/MyDrive/GNNOnImage/fmnist_emb_complete.pickle
# features copy shape  (70000, 600)
# 100% 70000/70000 [19:30<00:00, 59.80it/s]
# khop = False add = False
# ----Data statistics------'
#       #Edges 757752
#       #Classes 10
#       #Train samples 55000
#       #Val samples 5000
#       #Test samples 10000
# GAT(
#   (gat_layers): ModuleList(
#     (0): GATConv(
#       (fc): Linear(in_features=600, out_features=64, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
# ...

# %%
# !python3 /content/drive/MyDrive/GAT/dgl-master/examples/pytorch/ogb/ogbn-arxiv/gat.py \
                                                                 --dataset "fmnist" \
                                                                 --n-runs 5 \
                                                                 --use-norm \
                                                                 --use-labels \
                                                                 --no-attn-dst \
                                                                 --edge-drop 0.1 \
                                                                 --input-drop 0.1 \
                                                                 --early_stopping
# Out:
# Loading fmnist dataset.
# loading representations from  /content/drive/MyDrive/GNNOnImage/fmnist_emb_complete.pickle
# features copy shape  (70000, 600)
# 100% 70000/70000 [21:08<00:00, 55.17it/s]
# torch.Size([70000, 600])
# khop = False add = False
# ----Data statistics------'
#       #Edges 1250958
#       #Classes 10
#       #Train samples 55000
#       #Val samples 5000
#       #Test samples 10000
# ----------------------------------------
# Run: 1/5, Epoch: 20/2000, Average epoch time: 0.34  Patience 5 / 100
# Loss: 0.2448, Acc: 0.9226   Train/Val/Test loss: 0.2873/0.2785/0.3348
# Train/Val/Test/Best val/Final test acc: 0.9098/0.9126/0.8960/0.9428/0.9182
# ----------------------------------------
# Run: 1/5, Epoch: 40/2000, Average epoch time: 0.34  Patience 25 / 100
# Loss: 0.2483, Acc: 0.9166   Train/Val/Test loss: 0.2299/0.2043/0.2820
# Train/Val/Test/Best val/Final test acc: 0.9245/0.9316/0.9081/0.9428/0.9182
# ----------------------------------------
# ...
